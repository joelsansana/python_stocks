# %%
import pandas as pd

# %%
# !wget "https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_INNOVATION_ETF_ARKK_HOLDINGS.csv"
# Out:
# --2021-02-12 00:48:23--  https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_INNOVATION_ETF_ARKK_HOLDINGS.csv
# Resolving ark-funds.com (ark-funds.com)... 172.67.68.203, 104.26.2.121, 104.26.3.121, ...
# Connecting to ark-funds.com (ark-funds.com)|172.67.68.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Syntax error in Set-Cookie: ; HttpOnly; Secure at position 0.
# Length: 6654 (6.5K) [application/octet-stream]
# Saving to: ‘ARK_INNOVATION_ETF_ARKK_HOLDINGS.csv’
#
# ARK_INNOVATION_ETF_ 100%[===================>]   6.50K  --.-KB/s    in 0s
#
# 2021-02-12 00:48:24 (64.0 MB/s) - ‘ARK_INNOVATION_ETF_ARKK_HOLDINGS.csv’ saved [6654/6654]

# %%
# !wget "https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_AUTONOMOUS_TECHNOLOGY_&_ROBOTICS_ETF_ARKQ_HOLDINGS.csv"
# Out:
# --2021-02-12 00:48:39--  https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_AUTONOMOUS_TECHNOLOGY_&_ROBOTICS_ETF_ARKQ_HOLDINGS.csv
# Resolving ark-funds.com (ark-funds.com)... 172.67.68.203, 104.26.2.121, 104.26.3.121, ...
# Connecting to ark-funds.com (ark-funds.com)|172.67.68.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Syntax error in Set-Cookie: ; HttpOnly; Secure at position 0.
# Length: 5922 (5.8K) [application/octet-stream]
# Saving to: ‘ARK_AUTONOMOUS_TECHNOLOGY_&_ROBOTICS_ETF_ARKQ_HOLDINGS.csv’
#
# ARK_AUTONOMOUS_TECH 100%[===================>]   5.78K  --.-KB/s    in 0s
#
# 2021-02-12 00:48:39 (68.4 MB/s) - ‘ARK_AUTONOMOUS_TECHNOLOGY_&_ROBOTICS_ETF_ARKQ_HOLDINGS.csv’ saved [5922/5922]

# %%
# !wget "https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_NEXT_GENERATION_INTERNET_ETF_ARKW_HOLDINGS.csv"
# Out:
# --2021-02-12 00:48:54--  https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_NEXT_GENERATION_INTERNET_ETF_ARKW_HOLDINGS.csv
# Resolving ark-funds.com (ark-funds.com)... 104.26.3.121, 172.67.68.203, 104.26.2.121, ...
# Connecting to ark-funds.com (ark-funds.com)|104.26.3.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Syntax error in Set-Cookie: ; HttpOnly; Secure at position 0.
# Length: 6731 (6.6K) [application/octet-stream]
# Saving to: ‘ARK_NEXT_GENERATION_INTERNET_ETF_ARKW_HOLDINGS.csv’
#
# ARK_NEXT_GENERATION 100%[===================>]   6.57K  --.-KB/s    in 0s
#
# 2021-02-12 00:48:55 (74.9 MB/s) - ‘ARK_NEXT_GENERATION_INTERNET_ETF_ARKW_HOLDINGS.csv’ saved [6731/6731]

# %%
# !wget "https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_GENOMIC_REVOLUTION_MULTISECTOR_ETF_ARKG_HOLDINGS.csv"
# Out:
# --2021-02-12 00:57:16--  https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_GENOMIC_REVOLUTION_MULTISECTOR_ETF_ARKG_HOLDINGS.csv
# Resolving ark-funds.com (ark-funds.com)... 104.26.2.121, 104.26.3.121, 172.67.68.203, ...
# Connecting to ark-funds.com (ark-funds.com)|104.26.2.121|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Syntax error in Set-Cookie: ; HttpOnly; Secure at position 0.
# Length: 6764 (6.6K) [application/octet-stream]
# Saving to: ‘ARK_GENOMIC_REVOLUTION_MULTISECTOR_ETF_ARKG_HOLDINGS.csv’
#
# ARK_GENOMIC_REVOLUT 100%[===================>]   6.61K  --.-KB/s    in 0s
#
# 2021-02-12 00:57:16 (68.5 MB/s) - ‘ARK_GENOMIC_REVOLUTION_MULTISECTOR_ETF_ARKG_HOLDINGS.csv’ saved [6764/6764]

# %%
# !wget "https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_FINTECH_INNOVATION_ETF_ARKF_HOLDINGS.csv"
# Out:
# --2021-02-12 00:49:02--  https://ark-funds.com/wp-content/fundsiteliterature/csv/ARK_FINTECH_INNOVATION_ETF_ARKF_HOLDINGS.csv
# Resolving ark-funds.com (ark-funds.com)... 172.67.68.203, 104.26.2.121, 104.26.3.121, ...
# Connecting to ark-funds.com (ark-funds.com)|172.67.68.203|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Syntax error in Set-Cookie: ; HttpOnly; Secure at position 0.
# Length: 5999 (5.9K) [application/octet-stream]
# Saving to: ‘ARK_FINTECH_INNOVATION_ETF_ARKF_HOLDINGS.csv’
#
# ARK_FINTECH_INNOVAT 100%[===================>]   5.86K  --.-KB/s    in 0s
#
# 2021-02-12 00:49:02 (49.3 MB/s) - ‘ARK_FINTECH_INNOVATION_ETF_ARKF_HOLDINGS.csv’ saved [5999/5999]

# %%
dfK = pd.read_csv('ARK_INNOVATION_ETF_ARKK_HOLDINGS.csv')
dfK.dropna(inplace=True)
dfQ = pd.read_csv('ARK_AUTONOMOUS_TECHNOLOGY_&_ROBOTICS_ETF_ARKQ_HOLDINGS.csv')
dfQ.dropna(inplace=True)
dfW = pd.read_csv('ARK_NEXT_GENERATION_INTERNET_ETF_ARKW_HOLDINGS.csv')
dfW.dropna(inplace=True)
dfG = pd.read_csv('ARK_GENOMIC_REVOLUTION_MULTISECTOR_ETF_ARKG_HOLDINGS.csv')
dfG.dropna(inplace=True)
dfF = pd.read_csv('ARK_FINTECH_INNOVATION_ETF_ARKF_HOLDINGS.csv')
dfF.dropna(inplace=True)

# %%
dfK[:5]
# Out:
#         date  fund               company  ...     shares market value($)  weight(%)
# 0  2/11/2021  ARKK             TESLA INC  ...  2955229.0    2.398641e+09       8.70
# 1  2/11/2021  ARKK              ROKU INC  ...  4034033.0    1.878609e+09       6.81
# 2  2/11/2021  ARKK    TELADOC HEALTH INC  ...  4872935.0    1.382403e+09       5.01
# 3  2/11/2021  ARKK        SQUARE INC - A  ...  5166612.0    1.373957e+09       4.98
# 4  2/11/2021  ARKK  ZILLOW GROUP INC - C  ...  5089653.0    9.873927e+08       3.58
#
# [5 rows x 8 columns]

# %%
dfQ[:5]
# Out:
#         date  fund               company  ...     shares market value($)  weight(%)
# 0  2/11/2021  ARKQ             TESLA INC  ...   476511.0    3.867649e+08       9.65
# 1  2/11/2021  ARKQ  BAIDU INC - SPON ADR  ...   655316.0    2.028793e+08       5.06
# 2  2/11/2021  ARKQ           TRIMBLE INC  ...  2339857.0    1.709032e+08       4.26
# 3  2/11/2021  ARKQ            DEERE & CO  ...   526711.0    1.656295e+08       4.13
# 4  2/11/2021  ARKQ        JD.COM INC-ADR  ...  1672334.0    1.655611e+08       4.13
#
# [5 rows x 8 columns]

# %%
dfW[:5]
# Out:
#         date  fund  ... market value($) weight(%)
# 0  2/11/2021  ARKW  ...    7.502855e+08      8.36
# 1  2/11/2021  ARKW  ...    3.968361e+08      4.42
# 2  2/11/2021  ARKW  ...    3.698044e+08      4.12
# 3  2/11/2021  ARKW  ...    3.570687e+08      3.98
# 4  2/11/2021  ARKW  ...    3.386432e+08      3.77
#
# [5 rows x 8 columns]

# %%
dfG[:5]
# Out:
#         date  fund  ... market value($) weight(%)
# 0  2/11/2021  ARKG  ...    1.005065e+09      7.89
# 1  2/11/2021  ARKG  ...    8.705184e+08      6.83
# 2  2/11/2021  ARKG  ...    6.353725e+08      4.99
# 3  2/11/2021  ARKG  ...    5.355618e+08      4.20
# 4  2/11/2021  ARKG  ...    4.993523e+08      3.92
#
# [5 rows x 8 columns]

# %%
dfF[:5]
# Out:
#         date  fund  ... market value($) weight(%)
# 0  2/11/2021  ARKF  ...    3.992378e+08      8.99
# 1  2/11/2021  ARKF  ...    2.231359e+08      5.02
# 2  2/11/2021  ARKF  ...    1.994611e+08      4.49
# 3  2/11/2021  ARKF  ...    1.829747e+08      4.12
# 4  2/11/2021  ARKF  ...    1.601763e+08      3.61
#
# [5 rows x 8 columns]
